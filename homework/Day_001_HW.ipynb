# %% [markdown]
# 作業1：
#
# Two Sigma: Using News to Predict Stock Movements
# Use news analytics to predict stock price performance
# https://www.kaggle.com/c/two-sigma-financial-news
#
# 1. 你選的這組資料為何重要
# A.對股票預測有相當大的興趣
# B.分析新聞數據, 取得資料上來的公開方便
# c.龐大資料量和處理技巧有助於機器學習
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# A.提供者:
# 1.Market data (2007 to present) provided by Intrinio - contains financial market information such as opening price, closing price, trading volume, calculated returns, etc.
# 2.News data (2007 to present) Source: Thomson Reuters - contains information about news articles/alerts published about assets, such as article details, sentiment, and other commentary.
#
# 3. 蒐集而來的資料型態為何
# A.市場數據以及新聞數據(結構化：數值, 表格, ...etc)
#
# 4. 這組資料想解決的問題如何評估
# A.根據兩個數據來源預測未來的股票價格回報

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 假設以每個月的賺取金額當成業績的前提下, 應該要同時衡量載客的趟數和單次獲取金額
# 在兩者之間可以取得一個平衡
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# A.單次獲取金額
# B.每個月總載客次數
# C.行駛時間
# D.行駛里程數
# E.工作時間(早上, 大夜 ;假日, 平日)
# F.工作服務區域
# 資料可由規定之APP紀錄資料
#
# 3. 蒐集而來的資料型態為何
# (結構化：數值, 表格, ...etc)
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 應該多跑遠程賺取單趟高額, 或者多跑幾個近程單量越高情況下其獲利會較高
# 希望可以幫駕駛找到一個組合, 根據其需求提出不同建議

# %%
"""
作業三
"""
import numpy as np
import matplotlib.pyplot as plt

def mean_square_error(y, y_pred):

    mse = MSE = np.mean((y - y_pred)**2)
    return mse

MSE = mean_square_error(y, y_hat)
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean square error is 244.658

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.175
